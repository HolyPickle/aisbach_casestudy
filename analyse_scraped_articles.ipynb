# %%
import pandas as pd
import re

results_df = pd.read_csv('results/newspaper_results.csv')

# %%
def extract_investment_amount(content):
    # Regex patterns to extract investment amounts
    # Therse are generated with GPT
    investment_patterns = [
        r'\$\d+(?:,\d{3})*(?:\.\d+)?(?:m|b)?',  # Dollar amounts with commas, optionally followed by m or b
        r'€\d+(?:,\d{3})*(?:\.\d+)?(?:m|b)?',   # Euro amounts with commas, optionally followed by m or b
        r'\$\d+(?:,\d{3})*(?:\.\d+)?\s+m',      # Dollar amounts in millions with space
        r'\$\d+(?:,\d{3})*(?:\.\d+)?\s+b',      # Dollar amounts in billions with space
        r'€\d+(?:,\d{3})*(?:\.\d+)?\s+m',       # Euro amounts in millions with space
        r'€\d+(?:,\d{3})*(?:\.\d+)?\s+b',       # Euro amounts in billions with space
        r'\d+(?:,\d{3})*(?:\.\d+)?\s+dollars',  # Dollar amounts in words
        r'\d+(?:,\d{3})*(?:\.\d+)?\s+euros',    # Euro amounts in words
        r'\d+(?:,\d{3})*(?:\.\d+)?\s+million',  # Million amounts in words
        r'\d+(?:,\d{3})*(?:\.\d+)?\s+billion'   # Billion amounts in words
    ]
    investments = []
    for pattern in investment_patterns:
        matches = re.findall(pattern, content)
        investments.extend(matches)
    return investments

results_df['investments'] = results_df['final_content'].apply(extract_investment_amount)

# %%
def extract_solar_energy_info(content):
    # Regex patterns to extract solar energy production amounts
    # Therse are generated with GPT
    energy_patterns = [
    r'solar energy production\s*[:=]?\s*(\d+(\.\d+)?\s*(megawatts|gigawatts|kw|mw|gw))',
    r'produces (\d+(\.\d+)?)\s*(megawatts|gigawatts|kw|mw|gw) of solar energy',
    r'solar power\s*[:=]?\s*(\d+(\.\d+)?)\s*(megawatts|gigawatts|kw|mw|gw)',
    r'(\d+(\.\d+)?)\s*(megawatts|gigawatts|kw|mw|gw) of solar energy production',
    r'solar\s*(\d+(\.\d+)?)\s*(megawatts|gigawatts|kw|mw|gw)',
    r'(\d+(\.\d+)?)\s*(megawatts|gigawatts|kw|mw|gw)\s*solar',
    r'(\d+(\.\d+)?)\s*(megawatts|gigawatts|kw|mw|gw)',

    r'(\d+(\.\d+)?\s*megawatts)',
    r'(\d+(\.\d+)?\s*gigawatts)',
    r'(\d+(\.\d+)?\s*kilowatts)',
    r'(\d+(\.\d+)?\s*mw)',
    r'(\d+(\.\d+)?\s*gw)',
    r'(\d+(\.\d+)?\s*kw)'
]

    
    solar_energy = []
    for pattern in energy_patterns:
        matches = re.findall(pattern, content)
        solar_energy.extend(matches)
    
    return solar_energy

results_df['solar_energy'] = results_df['final_content'].apply(extract_solar_energy_info)

# %%
results_df.to_csv('results/final_results.csv', index=False)

# %%
results_df
# Out:
#      company                     source  \
# 0    Enviria                EU-Startups
# 1    Enviria                     Sifted
# 2    Enviria                    Tech.eu
# 3    Enviria             Renewables Now
# 4    Enviria  pv magazine International
# ..       ...                        ...
# 120   Merkle                  Südkurier
# 121   Merkle            The Merkle News
# 122   Merkle                    NOKZEIT
# 123   Merkle               Investopedia
# 124   Merkle            The Merkle News
#
#                                                  title  \
# 0    Frankfurt-based ENVIRIA secures €185 million t...
# 1    Solar panel startup Enviria secures $200m from...
# 2    Germany's Enviria targets commercial solar ene...
# 3    Galileo sheds interest in Enviria to BlackRock...
# 4            BlackRock invests $200 million in Enviria
# ..                                                 ...
# 120  (Anzeige) 10 Jahre Geba GmbH und ein Jahr Geba...
# 121  Will Mining Cryptocurrency in the Desert Using...
# 122  24. Dezember 2021 - Solarpark - „Made in Seckach“
# 123  Is Solar-Powered Cryptocurrency Mining the Nex...
# 124  Envion – Mobile Crypto Miner Deploys to Lowest...
#
#                                                   desc         date  \
# 0    ENVIRIA, Germany's leading commercial and indu...  29 Feb 2024
# 1    Frankfurt-based Enviria has secured $200m in e...  29 Feb 2024
# 2    German solar startup Enviria raises over $200M...  29 Feb 2024
# 3    Pan-European renewables developer Galileo Gree...   5 Mar 2024
# 4    BlackRock has invested €183 million ($200.2 mi...  11 Mar 2024
# ..                                                 ...          ...
# 120  Rickenbach (psc) Die Firma GEBA GmbH mit Sitz ...  23 Mar 2019
# 121  Mining Bitcoin or any other cryptocurrency is ...   5 Jul 2017
# 122  Auf diesem Gelände soll der Solarpark entstehe...  24 Dec 2021
# 123  In the search to make cryptocurrency mining pr...   7 Nov 2017
# 124  China's renewable energy sector wasted more th...  25 Dec 2017
#
#                                                   link  \
# 0    https://www.eu-startups.com/2024/02/frankfurt-...
# 1    https://sifted.eu/articles/enviria-blackrock-c...
# 2    https://tech.eu/2024/02/29/germanys-enviria-ta...
# 3    https://renewablesnow.com/news/galileo-sheds-i...
# 4    https://www.pv-magazine.com/2024/03/11/blackro...
# ..                                                 ...
# 120  https://www.suedkurier.de/region/hochrhein/ric...
# 121  https://themerkle.com/will-mining-cryptocurren...
# 122  https://www.nokzeit.de/2021/12/24/solarpark-ma...
# 123  https://www.investopedia.com/news/solarpowered...
# 124  https://themerkle.com/envion-mobile-crypto-min...
#
#                                       detailed_content  \
# 0    ENVIRIA, Germany’s leading commercial and indu...
# 1    Article `download()` failed with 403 Client Er...
# 2    Frankfurt-based Enviria has secured over $200 ...
# 3    Article `download()` failed with 403 Client Er...
# 4    BlackRock has agreed to invest €183 million in...
# ..                                                 ...
# 120  Rickenbach (psc) Die Firma GEBA GmbH mit Sitz ...
# 121  About The Author\n\nJP Buntinx is a FinTech an...
# 122  Auf diesem Gelände soll der Solarpark entstehe...
# 123  Cryptocurrency mining is a difficult and costl...
# 124  About The Author\n\nThe writer of this post is...
#
#                                          final_content  \
# 0    enviria, germany’s leading commercial and indu...
# 1    frankfurt-based enviria has secured $200m in e...
# 2    german solar startup enviria raises over $200m...
# 3    pan-european renewables developer galileo gree...
# 4    blackrock has invested €183 million ($200.2 mi...
# ..                                                 ...
# 120  rickenbach (psc) die firma geba gmbh mit sitz ...
# 121  mining bitcoin or any other cryptocurrency is ...
# 122  auf diesem gelände soll der solarpark entstehe...
# 123  in the search to make cryptocurrency mining pr...
# 124  china's renewable energy sector wasted more th...
#
#      investing_in_solarparks  \
# 0                       True
# 1                       True
# 2                       True
# 3                      False
# 4                      False
# ..                       ...
# 120                    False
# 121                    False
# 122                    False
# 123                     True
# 124                    False
#
#                                            investments  \
# 0    [$11, €185, $11 b, €185 m, 185 million, 11 bil...
# 1                                              [$200m]
# 2                                              [$200m]
# 3                                                   []
# 4    [$200.2, €183, $200.2 m, €183 m, 183 million, ...
# ..                                                 ...
# 120                                                 []
# 121                                                 []
# 122                                                 []
# 123                                                 []
# 124                                                 []
#
#                                           solar_energy
# 0    [(2.3, .3, gw), (1.7, .7, gw), (2.3gw, .3), (1...
# 1                                                   []
# 2                                                   []
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 120                                                 []
# 121                                                 []
# 122                              [(7, , mw), (7 mw, )]
# 123                                                 []
# 124                                                 []
#
# [125 rows x 11 columns]

# %% [markdown]
# It turned out all of the companies are investing in solar. Even the HIH Invest Real Estate Austria GmbH invested in solarpark shows an article published 21 Mar 2024. Link: https://realassets.ipe.com/news/hih-invest-buys-solar-park-in-southern-spain/10072345.article

# %% [markdown]
# ## Final Aggregations
# * We can convert all findings into numberical values and aggregate them to derive a final number for both inversment amount and generated energy
# * This numbers will not be reliable but can be useful to have an idea
# * For the labels, we can just take the max
# * However, due to my exams I cannot spend more time on this task. Results still can be inspected manually from the .csv file
